# %% [markdown]
# # Introduce `Pandas` part 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
empty_dataframe = pd.DataFrame(data=[None],
                               columns=[None],
                               index = [None],
                              )

# %%
empty_dataframe
# Out:
#       NaN
# NaN  None

# %%
marvel_df = pd.DataFrame(data=[
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
                            ],
                        columns=[
                            'super_name',
                            'sex',
                            'year',
                        ],)

# %%
marvel_df
# Out:
#           super_name     sex  year
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
marvel_df.index = marvel_df.super_name

# %%
marvel_df
# Out:
#                         super_name     sex  year
# super_name
# Spider-Man              Spider-Man    male  1962
# Captain America    Captain America    male  1941
# Wolverine                Wolverine    male  1974
# Iron Man                  Iron Man    male  1963
# Thor                          Thor    male  1963
# Thing                        Thing    male  1961
# Mister Fantastic  Mister Fantastic    male  1961
# Hulk                          Hulk    male  1962
# Beast                        Beast    male  1963
# Invisible Woman    Invisible Woman  female  1961
# Storm                        Storm  female  1975
# Namor                        Namor    male  1939
# Hawkeye                    Hawkeye    male  1964
# Daredevil                Daredevil    male  1964
# Doctor Strange      Doctor Strange    male  1963
# Hank Pym                  Hank Pym    male  1962
# Scarlet Witch        Scarlet Witch  female  1964
# Wasp                          Wasp  female  1963
# ...

# %% [markdown]
# marve

# %%
marvel_df.drop(['super_name'], axis=1)
# Out:
#                      sex  year
# super_name
# Spider-Man          male  1962
# Captain America     male  1941
# Wolverine           male  1974
# Iron Man            male  1963
# Thor                male  1963
# Thing               male  1961
# Mister Fantastic    male  1961
# Hulk                male  1962
# Beast               male  1963
# Invisible Woman   female  1961
# Storm             female  1975
# Namor               male  1939
# Hawkeye             male  1964
# Daredevil           male  1964
# Doctor Strange      male  1963
# Hank Pym            male  1962
# Scarlet Witch     female  1964
# Wasp              female  1963
# Black Widow       female  1964
# Vision              male  1968

# %%
marvel_df
# Out:
#                         super_name     sex  year
# super_name
# Spider-Man              Spider-Man    male  1962
# Captain America    Captain America    male  1941
# Wolverine                Wolverine    male  1974
# Iron Man                  Iron Man    male  1963
# Thor                          Thor    male  1963
# Thing                        Thing    male  1961
# Mister Fantastic  Mister Fantastic    male  1961
# Hulk                          Hulk    male  1962
# Beast                        Beast    male  1963
# Invisible Woman    Invisible Woman  female  1961
# Storm                        Storm  female  1975
# Namor                        Namor    male  1939
# Hawkeye                    Hawkeye    male  1964
# Daredevil                Daredevil    male  1964
# Doctor Strange      Doctor Strange    male  1963
# Hank Pym                  Hank Pym    male  1962
# Scarlet Witch        Scarlet Witch  female  1964
# Wasp                          Wasp  female  1963
# ...

# %%
marvel_df.drop(['Namor', 'Hank Pym'],axis=0)
# Out:
#                         super_name     sex  year
# super_name
# Spider-Man              Spider-Man    male  1962
# Captain America    Captain America    male  1941
# Wolverine                Wolverine    male  1974
# Iron Man                  Iron Man    male  1963
# Thor                          Thor    male  1963
# Thing                        Thing    male  1961
# Mister Fantastic  Mister Fantastic    male  1961
# Hulk                          Hulk    male  1962
# Beast                        Beast    male  1963
# Invisible Woman    Invisible Woman  female  1961
# Storm                        Storm  female  1975
# Hawkeye                    Hawkeye    male  1964
# Daredevil                Daredevil    male  1964
# Doctor Strange      Doctor Strange    male  1963
# Scarlet Witch        Scarlet Witch  female  1964
# Wasp                          Wasp  female  1963
# Black Widow            Black Widow  female  1964
# Vision                      Vision    male  1968

# %%
marvel_df[0:5]
# Out:
#                       super_name   sex  year
# super_name
# Spider-Man            Spider-Man  male  1962
# Captain America  Captain America  male  1941
# Wolverine              Wolverine  male  1974
# Iron Man                Iron Man  male  1963
# Thor                        Thor  male  1963

# %%
marvel_df.iloc[-5:]
# Out:
#                   super_name     sex  year
# super_name
# Hank Pym            Hank Pym    male  1962
# Scarlet Witch  Scarlet Witch  female  1964
# Wasp                    Wasp  female  1963
# Black Widow      Black Widow  female  1964
# Vision                Vision    male  1968

# %%
marvel_df.iloc[:5].sex.to_frame()
# Out:
#                   sex
# super_name
# Spider-Man       male
# Captain America  male
# Wolverine        male
# Iron Man         male
# Thor             male

# %%
marvel_df.iloc[0:-1].super_name.to_frame()
# Out:
#                         super_name
# super_name
# Spider-Man              Spider-Man
# Captain America    Captain America
# Wolverine                Wolverine
# Iron Man                  Iron Man
# Thor                          Thor
# Thing                        Thing
# Mister Fantastic  Mister Fantastic
# Hulk                          Hulk
# Beast                        Beast
# Invisible Woman    Invisible Woman
# Storm                        Storm
# Namor                        Namor
# Hawkeye                    Hawkeye
# Daredevil                Daredevil
# Doctor Strange      Doctor Strange
# Hank Pym                  Hank Pym
# Scarlet Witch        Scarlet Witch
# Wasp                          Wasp
# Black Widow            Black Widow

# %%
marvel_df.iloc[[0,-1]]
# Out:
#             super_name   sex  year
# super_name
# Spider-Man  Spider-Man  male  1962
# Vision          Vision  male  1968

# %%
marvel_df.loc['Vision', 'year'] = 1964

# %%
marvel_df
# Out:
#                         super_name     sex  year
# super_name
# Spider-Man              Spider-Man    male  1962
# Captain America    Captain America    male  1941
# Wolverine                Wolverine    male  1974
# Iron Man                  Iron Man    male  1963
# Thor                          Thor    male  1963
# Thing                        Thing    male  1961
# Mister Fantastic  Mister Fantastic    male  1961
# Hulk                          Hulk    male  1962
# Beast                        Beast    male  1963
# Invisible Woman    Invisible Woman  female  1961
# Storm                        Storm  female  1975
# Namor                        Namor    male  1939
# Hawkeye                    Hawkeye    male  1964
# Daredevil                Daredevil    male  1964
# Doctor Strange      Doctor Strange    male  1963
# Hank Pym                  Hank Pym    male  1962
# Scarlet Witch        Scarlet Witch  female  1964
# Wasp                          Wasp  female  1963
# ...

# %%
marvel_df['years_since'] = 2021 - marvel_df['year']

# %%
marvel_df
# Out:
#                         super_name     sex  year  years_since
# super_name
# Spider-Man              Spider-Man    male  1962           59
# Captain America    Captain America    male  1941           80
# Wolverine                Wolverine    male  1974           47
# Iron Man                  Iron Man    male  1963           58
# Thor                          Thor    male  1963           58
# Thing                        Thing    male  1961           60
# Mister Fantastic  Mister Fantastic    male  1961           60
# Hulk                          Hulk    male  1962           59
# Beast                        Beast    male  1963           58
# Invisible Woman    Invisible Woman  female  1961           60
# Storm                        Storm  female  1975           46
# Namor                        Namor    male  1939           82
# Hawkeye                    Hawkeye    male  1964           57
# Daredevil                Daredevil    male  1964           57
# ...

# %%
mask = marvel_df['sex'] == 'female'

# %%
mask
# Out:
# super_name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Namor               False
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Hank Pym            False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# Name: sex, dtype: bool

# %%
mask = marvel_df['sex'] == 'male'

# %%
mask
# Out:
# super_name
# Spider-Man           True
# Captain America      True
# Wolverine            True
# Iron Man             True
# Thor                 True
# Thing                True
# Mister Fantastic     True
# Hulk                 True
# Beast                True
# Invisible Woman     False
# Storm               False
# Namor                True
# Hawkeye              True
# Daredevil            True
# Doctor Strange       True
# Hank Pym             True
# Scarlet Witch       False
# Wasp                False
# Black Widow         False
# Vision               True
# Name: sex, dtype: bool

# %%
mask = marvel_df['year'] > 1970

# %%
mask
# Out:
# super_name
# Spider-Man          False
# Captain America     False
# Wolverine            True
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman     False
# Storm                True
# Namor               False
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Hank Pym            False
# Scarlet Witch       False
# Wasp                False
# Black Widow         False
# Vision              False
# Name: year, dtype: bool

# %%
marvel_df[mask]
# Out:
#            super_name     sex  year  years_since
# super_name
# Wolverine   Wolverine    male  1974           47
# Storm           Storm  female  1975           46

# %%
mask = (marvel_df['sex'] == 'female') & (marvel_df['year'] > 1970)
mask
# Out:
# super_name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman     False
# Storm                True
# Namor               False
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Hank Pym            False
# Scarlet Witch       False
# Wasp                False
# Black Widow         False
# Vision              False
# dtype: bool

# %%
marvel_df[mask]
# Out:
#            super_name     sex  year  years_since
# super_name
# Storm           Storm  female  1975           46

# %%
marvel_df.describe()
# Out:
#               year  years_since
# count    20.000000    20.000000
# mean   1961.650000    59.350000
# std       8.298859     8.298859
# min    1939.000000    46.000000
# 25%    1961.750000    57.000000
# 50%    1963.000000    58.000000
# 75%    1964.000000    59.250000
# max    1975.000000    82.000000

# %%
marvel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Spider-Man to Vision
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   super_name   20 non-null     object
#  1   sex          20 non-null     object
#  2   year         20 non-null     int64
#  3   years_since  20 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 1.3+ KB

# %%
marvel_df.shape
# Out:
# (20, 4)

# %%
marvel_df.head()
# Out:
#                       super_name   sex  year  years_since
# super_name
# Spider-Man            Spider-Man  male  1962           59
# Captain America  Captain America  male  1941           80
# Wolverine              Wolverine  male  1974           47
# Iron Man                Iron Man  male  1963           58
# Thor                        Thor  male  1963           58

# %%
x = marvel_df['year'].mean()
x
# Out:
# 1961.65

# %%
x = marvel_df['year'].min()
x
# Out:
# 1939

# %%
mask = marvel_df['year'] == marvel_df.year.min()

# %%
marvel_df[mask]
# Out:
#            super_name   sex  year  years_since
# super_name
# Namor           Namor  male  1939           82

# %%
# marvel_df = marvel_df.reset_index()

# %%
marvel_df
# Out:
#                         super_name     sex  year  years_since
# super_name
# Spider-Man              Spider-Man    male  1962           59
# Captain America    Captain America    male  1941           80
# Wolverine                Wolverine    male  1974           47
# Iron Man                  Iron Man    male  1963           58
# Thor                          Thor    male  1963           58
# Thing                        Thing    male  1961           60
# Mister Fantastic  Mister Fantastic    male  1961           60
# Hulk                          Hulk    male  1962           59
# Beast                        Beast    male  1963           58
# Invisible Woman    Invisible Woman  female  1961           60
# Storm                        Storm  female  1975           46
# Namor                        Namor    male  1939           82
# Hawkeye                    Hawkeye    male  1964           57
# Daredevil                Daredevil    male  1964           57
# ...

# %%
marvel_df['year']
# Out:
# super_name
# Spider-Man          1962
# Captain America     1941
# Wolverine           1974
# Iron Man            1963
# Thor                1963
# Thing               1961
# Mister Fantastic    1961
# Hulk                1962
# Beast               1963
# Invisible Woman     1961
# Storm               1975
# Namor               1939
# Hawkeye             1964
# Daredevil           1964
# Doctor Strange      1963
# Hank Pym            1962
# Scarlet Witch       1964
# Wasp                1963
# Black Widow         1964
# Vision              1964
# Name: year, dtype: int64

# %%
fun = marvel_df['year'].plot(kind='density',figsize=(14,5))
fun.axvline(marvel_df['year'].mean(),color='red')
fun.axvline(marvel_df['year'].median(), color='green')
fun.axvline(marvel_df['year'].min(), color='yellow')
fun.axvline(marvel_df['year'].max(), color='orange')

# %%
marvel_df['year'].plot(figsize=(14,6), kind='line')
# Out:
# <AxesSubplot:xlabel='super_name'>

# %%
marvel_df['year'].hist()

# %%
plt.hist(marvel_df['year'])
