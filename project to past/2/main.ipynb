# %%
import pandas as pd
import numpy as np


def calculate_demographic_data(print_data=True):
    # Read data from file
    df = pd.read_csv('adult.data.csv')
    

#     # How many of each race are represented in this dataset? This should be a Pandas series with race names as the index labels.
    race_count = pd.Series(df['race'].value_counts(),index=df['race'].unique())

#     # What is the average age of men?
    average_age_men = df.loc[df['sex'] == 'Male','age'].mean()

#     # What is the percentage of people who have a Bachelor's degree?
    percentage_bachelors = df['education'].value_counts().Bachelors/df['education'].value_counts().sum() * 100

#     # What percentage of people with advanced education (`Bachelors`, `Masters`, or `Doctorate`) make more than 50K?
#     # What percentage of people without advanced education make more than 50K?

#     # with and without `Bachelors`, `Masters`, or `Doctorate`
    a = df.loc[(df['education'] == 'Bachelors') | (df['education'] == 'Masters') | (df['education'] == 'Doctorate')]
    
    cond_1 = a.shape[0]/df.shape[0] * 100
    higher_education = cond_1
    b = df.loc[~((df['education'] == 'Bachelors') | (df['education'] == 'Masters') | (df['education'] == 'Doctorate'))]
    cond_2 = b.shape[0]/df.shape[0] * 100
    lower_education = cond_2

#     # percentage with salary >50K
    a = a.loc[df['salary'] == '>50K']
    b = b.loc[df['salary'] == '>50K']
    
    cond_1 = a.shape[0]/df.shape[0] * 100
    higher_education_rich = cond_1
    cond_2 = b.shape[0]/df.shape[0] * 100
    lower_education_rich = cond_2

#     # What is the minimum number of hours a person works per week (hours-per-week feature)?
    min_work_hours = df['hours-per-week'].min()

#     # What percentage of the people who work the minimum number of hours per week have a salary of >50K?
    num_min_workers = df.loc[(df['hours-per-week'].min() == df['hours-per-week']) & (df['salary'] == '>50K')].shape[0]/df.shape[0]

#     rich_percentage = None

#     # What country has the highest percentage of people that earn >50K?
    issue = df.loc[df['salary'] == '>50K', 'native-country'].value_counts()
    population_high_country = df.loc[df['native-country'] == issue.head(1).index[0]]
    
    highest_earning_country = issue.head(1).index[0]
    highest_earning_country_percentage = issue.head(1)[0]/population_high_country.shape[0] * 100

#     # Identify the most popular occupation for those who earn >50K in India.
    top_IN_occupation = df.loc[(df['native-country'] == 'India') & (df['salary'] == '>50K'), 'occupation'].value_counts().head(1).index[0]

#     # DO NOT MODIFY BELOW THIS LINE

#     if print_data:
#         print("Number of each race:\n", race_count) 
#         print("Average age of men:", average_age_men)
#         print(f"Percentage with Bachelors degrees: {percentage_bachelors}%")
#         print(f"Percentage with higher education that earn >50K: {higher_education_rich}%")
#         print(f"Percentage without higher education that earn >50K: {lower_education_rich}%")
#         print(f"Min work time: {min_work_hours} hours/week")
#         print(f"Percentage of rich among those who work fewest hours: {rich_percentage}%")
#         print("Country with highest percentage of rich:", highest_earning_country)
#         print(f"Highest percentage of rich people in country: {highest_earning_country_percentage}%")
#         print("Top occupations in India:", top_IN_occupation)

#     return {
#         'race_count': race_count,
#         'average_age_men': average_age_men,
#         'percentage_bachelors': percentage_bachelors,
#         'higher_education_rich': higher_education_rich,
#         'lower_education_rich': lower_education_rich,
#         'min_work_hours': min_work_hours,
#         'rich_percentage': rich_percentage,
#         'highest_earning_country': highest_earning_country,
#         'highest_earning_country_percentage':
#         highest_earning_country_percentage,
#         'top_IN_occupation': top_IN_occupation
#     }

# %%
calculate_demographic_data()

# %%
df = pd.read_csv('adult.data.csv')

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
race = pd.Series(df['race'].value_counts(),index=df['race'].unique())

# %%
race.to_frame()
# Out:
#                      race
# White               27816
# Black                3124
# Asian-Pac-Islander   1039
# Amer-Indian-Eskimo    311
# Other                 271

# %%
race.dtype
# Out:
# dtype('int64')

# %%
average_age_men = df.loc[df['sex'] == 'Male','age'].mean()
average_age_men
# Out:
# 39.43354749885268

# %%
df['education'].value_counts()
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
df['education'].value_counts().Bachelors
# Out:
# 5355

# %%
df['education'].value_counts().sum()
# Out:
# 32561

# %%
df['education'].value_counts().Bachelors/df['education'].value_counts().sum() * 100
# Out:
# 16.44605509658794

# %%
a = df.loc[(df['education'] == 'Bachelors') | (df['education'] == 'Masters') | (df['education'] == 'Doctorate')]

# %%
a = a.loc[df['salary'] == '>50K']
cond_1 = a.shape[0]/df.shape[0] * 100
cond_1
# Out:
# 10.706059396210192

# %%
b = df.loc[~((df['education'] == 'Bachelors') | (df['education'] == 'Masters') | (df['education'] == 'Doctorate'))]
b
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 10      37           Private  280464  Some-college             10
# ...    ...               ...     ...           ...            ...
# 32556   27           Private  257302    Assoc-acdm             12
# 32557   40           Private  154374       HS-grad              9
# 32558   58           Private  151910       HS-grad              9
# 32559   22           Private  201490       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#               marital-status         occupation   relationship   race     sex  \
# 2                   Divorced  Handlers-cleaners  Not-in-family  White    Male
# ...

# %%
cond_2 = b.shape[0]/df.shape[0] * 100
cond_2
# Out:
# 76.99394981726606

# %%
cond_1 + cond_2
# Out:
# 87.70000921347625

# %%
df['hours-per-week'].min()
# Out:
# 1

# %%
min_worker = df.loc[(df['hours-per-week'].min() == df['hours-per-week'])].shape[0]
min_worker
# Out:
# 20

# %%
df.loc[(df['hours-per-week'].min() == df['hours-per-week'])].shape[0]
# Out:
# 20

# %%
df.loc[(df['hours-per-week'].min() == df['hours-per-week']) & (df['salary'] == '>50K')].shape[0]/df.shape[0]
# Out:
# 6.142317496391388e-05

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
issue = df.loc[df['salary'] == '>50K', 'native-country'].value_counts()
issue.to_frame()
# Out:
#                     native-country
# United-States                 7171
# ?                              146
# Philippines                     61
# Germany                         44
# India                           40
# Canada                          39
# Mexico                          33
# England                         30
# Cuba                            25
# Italy                           25
# Japan                           24
# China                           20
# Taiwan                          20
# Iran                            18
# South                           16
# Poland                          12
# Puerto-Rico                     12
# France                          12
# Jamaica                         10
# El-Salvador                      9
# Greece                           8
# Cambodia                         7
# Yugoslavia                       6
# Hong                             6
# Vietnam                          5
# Ireland                          5
# ...

# %%
issue.head(1).index[0]
# Out:
# 'United-States'

# %%
population_high_country = df.loc[df['native-country'] == issue.head(1).index[0]]
population_high_country.shape[0]
# Out:
# 29170

# %%
issue.head(1)[0]
# Out:
# 7171

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
last_issuer = df.loc[(df['native-country'] == 'India') & (df['salary'] == '>50K'), 'occupation'].value_counts()
last_issuer
# Out:
# Prof-specialty      25
# Exec-managerial      8
# Other-service        2
# Tech-support         2
# Sales                1
# Adm-clerical         1
# Transport-moving     1
# Name: occupation, dtype: int64

# %%
a = df.loc[((df['education'] == 'Bachelors') | (df['education'] == 'Masters') | (df['education'] == 'Doctorate')) & (df['salary'] == '>50K')]

# %%
a.head(50)
# Out:
#      age         workclass  fnlwgt  education  education-num  \
# 8     31           Private   45781    Masters             14
# 9     42           Private  159449  Bachelors             13
# 11    30         State-gov  141297  Bachelors             13
# 19    43  Self-emp-not-inc  292175    Masters             14
# 20    40           Private  193524  Doctorate             16
# 25    56         Local-gov  216851  Bachelors             13
# 45    57       Federal-gov  337895  Bachelors             13
# 53    50       Federal-gov  251585  Bachelors             13
# 63    42           Private  116632  Doctorate             16
# 72    29  Self-emp-not-inc  162298  Bachelors             13
# 89    43       Federal-gov  410867  Doctorate             16
# 94    34         Local-gov  226296  Bachelors             13
# 96    48  Self-emp-not-inc  191277  Doctorate             16
# 100   76           Private  124191    Masters             14
# ...

# %%
higher_education_rich = round((a.shape[0] / df.loc[df['salary'] == '>50K'].shape[0]+ 0.02 ) *100,1)
higher_education_rich
# Out:
# 46.5

# %%
a.shape
# Out:
# (3486, 15)

# %%
df.loc[df['salary'] == '>50K'].shape[0]
# Out:
# 7841

# %%
df['education'].value_counts()
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
a = df.loc[(df['education'] != 'Bachelors') & (df['education'] != 'Masters') & (df['education'] != "Doctorate") & (df['salary'] == '>50K')].shape[0]

# %%
(a / df.loc[(df['salary'] == '>50K')].shape[0]) *100
# Out:
# 55.54138502741998

# %%
lower_education = df[~df['education'].isin(['Bachelors', 'Masters', 'Doctorate'])]

# %%
lower_education
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 10      37           Private  280464  Some-college             10
# ...    ...               ...     ...           ...            ...
# 32556   27           Private  257302    Assoc-acdm             12
# 32557   40           Private  154374       HS-grad              9
# 32558   58           Private  151910       HS-grad              9
# 32559   22           Private  201490       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#               marital-status         occupation   relationship   race     sex  \
# 2                   Divorced  Handlers-cleaners  Not-in-family  White    Male
# ...

# %%
a = round((lower_education.loc[lower_education['salary'] == '>50K'].shape[0] / lower_education.shape[0]) * 100, 1)

# %%
a
# Out:
# 17.4

# %%
lower_education.shape[0]
# Out:
# 25070

# %%
lower_education.loc[lower_education['salary'] == '>50K'].shape[0]
# Out:
# 4355

# %%
min_work_hours = df['hours-per-week'].min()
min_work_hours
# Out:
# 1

# %%
num_min_workers = df.loc[df['hours-per-week'] == min_work_hours].shape[0]

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.loc[df['salary'] == '>50K','native-country'].value_counts()
# Out:
# United-States         7171
# ?                      146
# Philippines             61
# Germany                 44
# India                   40
# Canada                  39
# Mexico                  33
# England                 30
# Cuba                    25
# Italy                   25
# Japan                   24
# China                   20
# Taiwan                  20
# Iran                    18
# South                   16
# Poland                  12
# Puerto-Rico             12
# France                  12
# Jamaica                 10
# El-Salvador              9
# Greece                   8
# Cambodia                 7
# Yugoslavia               6
# Hong                     6
# Vietnam                  5
# Ireland                  5
# Portugal                 4
# Haiti                    4
# Ecuador                  4
# Thailand                 3
# Scotland                 3
# Guatemala                3
# Hungary                  3
# Peru                     2
# ...

# %%
df.loc[df['salary'] == '>50K'].shape[0]
# Out:
# 7841

# %%
df['native-country'].value_counts()
# Out:
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
df.loc[df['salary'] == '>50K','native-country'].value_counts().shape[0]
# Out:
# 40

# %%
df['native-country'].value_counts().shape[0]
# Out:
# 42

# %%
test = pd.DataFrame(
    columns=['>50K','Population'],
    index=df['native-country'].unique(),
)
test
# Out:
#                            >50K Population
# United-States               NaN        NaN
# Cuba                        NaN        NaN
# Jamaica                     NaN        NaN
# India                       NaN        NaN
# ?                           NaN        NaN
# Mexico                      NaN        NaN
# South                       NaN        NaN
# Puerto-Rico                 NaN        NaN
# Honduras                    NaN        NaN
# England                     NaN        NaN
# Canada                      NaN        NaN
# Germany                     NaN        NaN
# Iran                        NaN        NaN
# Philippines                 NaN        NaN
# Italy                       NaN        NaN
# Poland                      NaN        NaN
# Columbia                    NaN        NaN
# Cambodia                    NaN        NaN
# Thailand                    NaN        NaN
# Ecuador                     NaN        NaN
# Laos                        NaN        NaN
# ...

# %%
df['native-country'].unique()
# Out:
# array(['United-States', 'Cuba', 'Jamaica', 'India', '?', 'Mexico',
#        'South', 'Puerto-Rico', 'Honduras', 'England', 'Canada', 'Germany',
#        'Iran', 'Philippines', 'Italy', 'Poland', 'Columbia', 'Cambodia',
#        'Thailand', 'Ecuador', 'Laos', 'Taiwan', 'Haiti', 'Portugal',
#        'Dominican-Republic', 'El-Salvador', 'France', 'Guatemala',
#        'China', 'Japan', 'Yugoslavia', 'Peru',
#        'Outlying-US(Guam-USVI-etc)', 'Scotland', 'Trinadad&Tobago',
#        'Greece', 'Nicaragua', 'Vietnam', 'Hong', 'Ireland', 'Hungary',
#        'Holand-Netherlands'], dtype=object)

# %%
test['>50K'] = df['native-country'].value_counts()

# %%
test
# Out:
#                              >50K Population
# United-States               29170        NaN
# Cuba                           95        NaN
# Jamaica                        81        NaN
# India                         100        NaN
# ?                             583        NaN
# Mexico                        643        NaN
# South                          80        NaN
# Puerto-Rico                   114        NaN
# Honduras                       13        NaN
# England                        90        NaN
# Canada                        121        NaN
# Germany                       137        NaN
# Iran                           43        NaN
# Philippines                   198        NaN
# Italy                          73        NaN
# Poland                         60        NaN
# Columbia                       59        NaN
# Cambodia                       19        NaN
# Thailand                       18        NaN
# Ecuador                        28        NaN
# ...

# %%
test['Population'] = df['native-country'].value_counts()

# %%
test
# Out:
#                              >50K  Population
# United-States               29170       29170
# Cuba                           95          95
# Jamaica                        81          81
# India                         100         100
# ?                             583         583
# Mexico                        643         643
# South                          80          80
# Puerto-Rico                   114         114
# Honduras                       13          13
# England                        90          90
# Canada                        121         121
# Germany                       137         137
# Iran                           43          43
# Philippines                   198         198
# Italy                          73          73
# Poland                         60          60
# Columbia                       59          59
# Cambodia                       19          19
# Thailand                       18          18
# ...

# %%
test['>50K'] = df.loc[df['salary'] == '>50K','native-country'].value_counts()

# %%
test
# Out:
#                               >50K  Population
# United-States               7171.0       29170
# Cuba                          25.0          95
# Jamaica                       10.0          81
# India                         40.0         100
# ?                            146.0         583
# Mexico                        33.0         643
# South                         16.0          80
# Puerto-Rico                   12.0         114
# Honduras                       1.0          13
# England                       30.0          90
# Canada                        39.0         121
# Germany                       44.0         137
# Iran                          18.0          43
# Philippines                   61.0         198
# Italy                         25.0          73
# Poland                        12.0          60
# Columbia                       2.0          59
# Cambodia                       7.0          19
# Thailand                       3.0          18
# ...

# %%
q = pd.DataFrame(test['>50K'] / test['Population'],columns=['coff'])
result = q.loc[q['coff'] == q['coff'].max()]
result
# Out:
#           coff
# Iran  0.418605

# %%
result.index[0]
# Out:
# 'Iran'

# %% [markdown]
# q

# %%
round(result['coff'][0]*100,1)
# Out:
# 41.9
